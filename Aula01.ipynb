# %%
import pyautogui as pa
import pyperclip as pp
import pandas as pd
from time import sleep

sleep(2)
pa.PAUSE = 1

#Passo 1: Entrar no sistema da empresa(no link do drive)
pa.hotkey('ctrl', 't')
pp.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')
pa.hotkey('ctrl', 'v')
pa.press('enter')
sleep(5)

#Passo 2: Navegar até o local do relatório (entrar na pasta exportar)
pa.click(x=372, y=314, clicks=2)
sleep(2)

#Passo 3: Exportar o relatório (Fazer o download)
pa.click(x=392, y=378)
pa.click(x=1241, y=186)
pa.click(x=1026, y=620)
sleep(10)

# %%
#Passo 4: Calcular os indicadores (faturamento e quantidade de produtos)
tabela = pd.read_excel(r'C:\Users\Redsik\Downloads\Vendas - Dez.xlsx')
display(tabela)

faturamento = tabela['Valor Final'].sum()
quantidade = tabela['Quantidade'].sum()
print(f'R$ {faturamento},00 - QTD: {quantidade}')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#Passo 5: Enviar um email para a diretoria

#abrir aba e entrar no email
pa.hotkey('ctrl', 't')
pp.copy('https://outlook.live.com/mail/0/')
pa.hotkey('ctrl', 'v')
pa.press('enter')
sleep(5)

#clicar no botão escrever
pa.click(x=160, y=211)
sleep(2)

#preencher as informações do email
pa.write('talles_correa@hotmail.com')
pa.press('tab')
pa.press('tab')
pp.copy('Relatório de vendas')
pa.hotkey('ctrl', 'v')
pa.press('tab')
texto = f'''Prezados, bom dia

O faturamento de ontem foi de: R$ {faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,.2f} unidades.

Abs,
Talitos'''
pp.copy(texto)
pa.hotkey('ctrl', 'v')


#enviar o email
pa.hotkey('ctrl', 'enter')

# %%
sleep(5)
pa.position()
# Out:
# Point(x=160, y=211)
